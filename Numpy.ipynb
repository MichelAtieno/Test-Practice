# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#BROADCASTING
a = np.arange(6).reshape(3,2)
b = np.array([[10], [20], [30]])
a+b
# Out:
# array([[10, 11],
#        [22, 23],
#        [34, 35]])

# %%
x = np.arange(5)
y = np.random.randn(5)
plt.plot(x,y)
plt.show()
